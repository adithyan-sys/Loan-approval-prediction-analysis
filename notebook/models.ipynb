# %% [markdown]
# # Model Building codes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# ml models

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from imblearn.over_sampling import SMOTE

print("\n Library imports successful!")
# Out:
#  Library imports successful!

# %% [markdown]
# ### Fecting the data

# %%
main_df = pd.read_csv(r"C:\Users\lenovo\OneDrive\Documents\Loan approval prediction\Data\loan_prediction.csv")
print("\n Dataset loaded successfully!")

main_df.head()
# Out:
#  Dataset loaded successfully!
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# ...

# %%
main_df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 67.2+ KB

# %% [markdown]
# ### Cleaning and Evaluvating the data

# %%
main_df.columns.tolist()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
main_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=main_df)
plt.title("Box Plot for Numerical Features")
# Out:
# Text(0.5, 1.0, 'Box Plot for Numerical Features')

# %%
main_df['LoanAmount'] = main_df['LoanAmount'].fillna(main_df['LoanAmount'].median())
main_df[ 'Loan_Amount_Term'] = main_df['Loan_Amount_Term'].fillna(main_df['Loan_Amount_Term'].mean())
main_df['Credit_History'] = main_df['Credit_History'].fillna(main_df['Credit_History'].mean())

# %%
main_df['LoanAmount'].median()
# Out:
# 128.0

# %%
main_df['LoanAmount'].mean()
# Out:
# np.float64(145.75244299674267)

# %%
# Martial status 
main_df['Gender'] = main_df['Gender'].fillna(main_df['Gender'].mode()[0])
main_df['Married'] = main_df['Married'].fillna(main_df['Married'].mode()[0])
main_df['Dependents'] = main_df['Dependents'].fillna(main_df['Dependents'].mode()[0])
 
# self-employ jobs
main_df['Self_Employed'] = main_df['Self_Employed'].fillna(main_df['Self_Employed'].mode()[0])

# %%
main_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
print("number of peoples with loan approval: ", main_df['Loan_Status'].value_counts()[0])
print("number of peoples with loan rejection: ", main_df['Loan_Status'].value_counts()[1])
plt.figure(figsize=(6, 4))
sns.countplot(x='Loan_Status', data=main_df)
# Out:
# number of peoples with loan approval:  422
# number of peoples with loan rejection:  192
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
print("number of peoples with employed: ", main_df['Self_Employed'].value_counts()[1])
print("number of peoples with not employed: ", main_df['Self_Employed'].value_counts()[0])
plt.figure(figsize=(6, 4))
sns.countplot(x='Self_Employed', data=main_df)
# Out:
# number of peoples with employed:  82
# number of peoples with not employed:  532
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
print("number of people who took loan according to Gender: ")
print(main_df['Gender'].value_counts())
sns.countplot(x = 'Gender', data = main_df, palette = 'Set2')
# Out:
# number of people who took loan according to Gender:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print("number of people who took loan according to martial status: ")
print(main_df['Married'].value_counts())
sns.countplot(x = 'Married', data = main_df, palette = 'Set2')
# Out:
# number of people who took loan according to martial status:
# Married
# Yes    401
# No     213
# Name: count, dtype: int64
# <Axes: xlabel='Married', ylabel='count'>

# %%
numeric_df = main_df.select_dtypes(include='number')
corr = numeric_df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
corr
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.565181
# CoapplicantIncome        -0.116605           1.000000    0.189218
# LoanAmount                0.565181           0.189218    1.000000
# Loan_Amount_Term         -0.045242          -0.059675    0.039235
# Credit_History           -0.014477          -0.001665   -0.007031
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045242       -0.014477
# CoapplicantIncome         -0.059675       -0.001665
# LoanAmount                 0.039235       -0.007031
# Loan_Amount_Term           1.000000        0.001395
# Credit_History             0.001395        1.000000

# %%
main_df['total_income'] = main_df['ApplicantIncome'] + main_df['CoapplicantIncome']
main_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  total_income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
main_df['ApplicantIncome_Log'] = np.log(main_df['ApplicantIncome'] + 1)
sns.displot(main_df['ApplicantIncome_Log'],kde=True)

# %%
main_df['total_income_Log'] = np.log(main_df['total_income'] + 1)
sns.displot(main_df['total_income_Log'],kde=True)

# %%
main_df['LoanAmount_Log'] = np.log(main_df['LoanAmount'] + 1)
sns.displot(main_df['LoanAmount_Log'],kde=True)

# %%
main_df['Loan_Amount_Term_Log'] = np.log(main_df['Loan_Amount_Term'] + 1)
sns.distplot(main_df['Loan_Amount_Term_Log'],kde=True)
# Out:
# <Axes: xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
main_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  total_income  \
# 0             1.0         Urban           Y        5849.0
# ...

# %%
# Removing specific columns that are not needed for modeling
cols = ['CoapplicantIncome', 'ApplicantIncome', 'LoanAmount', 'Loan_Amount_Term','total_income','Loan_ID']
main_df = main_df.drop(columns=cols, axis=1)
main_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncome_Log  total_income_Log  \
# 0         Urban           Y             8.674197          8.674197
# 1         Rural           N             8.430327          8.714732
# 2         Urban           Y             8.006701          8.006701
# 3         Urban           Y             7.857094          8.505525
# 4         Urban           Y             8.699681          8.699681
#
#    LoanAmount_Log  Loan_Amount_Term_Log
# 0        4.859812              5.888878
# 1        4.859812              5.888878
# ...

# %% [markdown]
# ## Encoding the data

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender', 'Married', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
le = LabelEncoder()
for col in cols:
    main_df[col] = le.fit_transform(main_df[col])

# %%
main_df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0          0          0              0             1.0
# 1       1        1          1          0              0             1.0
# 2       1        1          0          0              1             1.0
# 3       1        1          0          1              0             1.0
# 4       1        0          0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncome_Log  total_income_Log  \
# 0              2            1             8.674197          8.674197
# 1              0            0             8.430327          8.714732
# 2              2            1             8.006701          8.006701
# 3              2            1             7.857094          8.505525
# 4              2            1             8.699681          8.699681
#
#    LoanAmount_Log  Loan_Amount_Term_Log
# 0        4.859812              5.888878
# ...

# %%
main_df.dtypes
# Out:
# Gender                    int64
# Married                   int64
# Dependents               object
# Education                 int64
# Self_Employed             int64
# Credit_History          float64
# Property_Area             int64
# Loan_Status               int64
# ApplicantIncome_Log     float64
# total_income_Log        float64
# LoanAmount_Log          float64
# Loan_Amount_Term_Log    float64
# dtype: object
